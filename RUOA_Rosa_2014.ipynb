# %% [markdown]
# **Datos del mes de junio-diciembre del 2014**
#
#
# Rosa de los vientos mensual y anual

# %% [markdown]
# **Cargar paqueterías**

# %%
using DataFrames

# %%
using CSV

# %%
using PyPlot

# %% [markdown]
# **Cargar datos**

# %%
Datos1=readtable("2014-06-JQRO_minuto_L1-F.csv");
Datos2=readtable("2014-07-JQRO_minuto_L1-F.csv");
Datos3=readtable("2014-08-JQRO_minuto_L1-F.csv");
Datos4=readtable("2014-09-JQRO_minuto_L1-F.csv");
Datos5=readtable("2014-10-JQRO_minuto_L1-F.csv");
Datos6=readtable("2014-11-JQRO_minuto_L1-F.csv");
Datos7=readtable("2014-12-JQRO_minuto_L1-F.csv");

# %%
#Modifico la variable de tiempo junio
Tiempo1 = DateTime[]
for i=1:length(Datos1[:,1])

    push!(Tiempo1,DateTime(Datos1[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo ju1io
Tiempo2 = DateTime[]
for i=1:length(Datos2[:,1])

    push!(Tiempo2,DateTime(Datos2[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo agosto
Tiempo3 = DateTime[]
for i=1:length(Datos3[:,1])

    push!(Tiempo3,DateTime(Datos3[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo septiembre
Tiempo4 = DateTime[]
for i=1:length(Datos4[:,1])

    push!(Tiempo4,DateTime(Datos4[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo octubre
Tiempo5 = DateTime[]
for i=1:length(Datos5[:,1])

    push!(Tiempo5,DateTime(Datos5[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo noviembre
Tiempo6 = DateTime[]
for i=1:length(Datos6[:,1])

    push!(Tiempo6,DateTime(Datos6[i,1],"d/m/y HH:MM"))
    
end

# %%
#Modifico la variable de tiempo diciembre
Tiempo7 = DateTime[]
for i=1:length(Datos7[:,1])

    push!(Tiempo7,DateTime(Datos7[i,1],"d/m/y HH:MM"))
    
end

# %%
 #Omito missing de la velocidad del viento
VelViento1=collect(skipmissing(Datos1[:, 4])); VelViento2=collect(skipmissing(Datos2[:, 4])); VelViento3=collect(skipmissing(Datos3[:, 4])); VelViento4=collect(skipmissing(Datos4[:, 4])); VelViento5=collect(skipmissing(Datos5[:, 4])); VelViento6=collect(skipmissing(Datos6[:, 4])); VelViento7=collect(skipmissing(Datos7[:, 4])); 

 #Omito missing de la dirección del tiempo
DirViento1=collect(skipmissing(Datos1[:, 6])); DirViento2=collect(skipmissing(Datos2[:, 6])); DirViento3=collect(skipmissing(Datos3[:, 6])); DirViento4=collect(skipmissing(Datos4[:, 6])); DirViento5=collect(skipmissing(Datos5[:, 6])); DirViento6=collect(skipmissing(Datos6[:, 6])); DirViento7=collect(skipmissing(Datos7[:, 6]));

# %% [markdown]
# **Rosa de los vientos: Junio**

# %%
theta = DirViento1 #Dirección promedio del viento
r = VelViento1 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("1pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, junio 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos: Julio**

# %%
theta = DirViento2 #Dirección promedio del viento
r = VelViento2 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("2pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, julio 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos: Agosto**

# %%
theta = DirViento3 #Dirección promedio del viento
r = VelViento3 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("3pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, agosto 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos: Septiembre**

# %%
theta = DirViento4 #Dirección promedio del viento
r = VelViento4 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("4pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, septiembre 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos: Octubre**

# %%
theta = DirViento5 #Dirección promedio del viento
r = VelViento5 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("5pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, octubre 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyError (ccall(@pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, arg, kw)) <type 'exceptions.ValueError'>
# ValueError('shape mismatch: objects cannot be broadcast to a single shape',)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 2770, in bar
#     ret = ax.bar(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1855, in inner
#     return func(ax, *args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py", line 2233, in bar
#     np.atleast_1d(x), height, width, y, linewidth)
#   File "/usr/local/lib/python2.7/dist-packages/numpy/lib/stride_tricks.py", line 249, in broadcast_arrays
#     shape = _broadcast_shape(*args)
#   File "/usr/local/lib/python2.7/dist-packages/numpy/lib/stride_tricks.py", line 184, in _broadcast_shape
#     b = np.broadcast(*args[:32])
#
#
# Stacktrace:
#  [1] pyerr_check at /home/jrun/.julia/v0.6/PyCall/src/exception.jl:60 [inlined]
# ...

# %% [markdown]
# **Rosa de los vientos: Noviembre**

# %%
theta = DirViento6 #Dirección promedio del viento
r = VelViento6 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("6pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, noviembre 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos: Diciembre**

# %%
theta = DirViento7 #Dirección promedio del viento
r = VelViento7 #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("7pyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos, Diciembre 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)

# %% [markdown]
# **Rosa de los vientos anual**

# %%
DirVientoA=getindex([DirViento1, DirViento2, DirViento3, DirViento4, DirViento6, DirViento7]); #Arreglo para meses

# %%
VelVientoA=getindex([VelViento1, VelViento2, VelViento3, VelViento4, VelViento6, VelViento7]); #Arreglo para meses

# %%
theta = DirVientoA #Dirección promedio del viento
r = VelVientoA #Vel prom del viento
width = 2pi/(length(theta))

fig = figure("Apyplot_windrose_barplot",figsize=(10,10)) # Crea una nueva figura
ax = axes(polar="true") # Crea una gráfica polar
title("Rosa de los vientos 2014")
b = bar(theta,r,width=width, color="darkred") # Gráfica de barras

dtheta = 20
ax[:set_thetagrids]([0:dtheta:360-dtheta;]) # Grid de 0 a 360 en incremento de theta
ax[:set_theta_zero_location]("N") # 0 grados en la parte superior
ax[:set_theta_direction](-1) # Sentido a las manecillas del reloj
fig[:canvas][:draw]() # Actualiza la figura
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x1000 with 1 Axes>)
